# %% [markdown]
# #Bhumika Verma(19BCE1418)

# %%
from nltk.corpus.reader import WordListCorpusReader
from google.colab import files
uploaded = files.upload()
x = WordListCorpusReader(".", uploaded)
x.words()
# Out:
#      <input type="file" id="files-62a6a009-a04c-40c8-8135-fc8bf7f15015" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62a6a009-a04c-40c8-8135-fc8bf7f15015">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nlp da2_a.txt to nlp da2_a.txt
# ...

# %% [markdown]
# ## Word Segmentation

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

print(word_tokenize(x.raw()))
# Out:
# ['There', '’', 's', 'nothing', 'quite', 'like', 'the', 'terror', 'writes', 'of', 'the', 'hypothetical', 'question', '.', 'Especially', 'when', 'it', 'is', 'a', 'written', 'product', 'of', 'the', 'interviewer', '’', 's', 'rich', 'imagination', '.', 'We', '’', 'll', 'talk', 'more', 'about', 'these', 'devils', 'in', 'Chapter', '7', '.', 'But', 'for', 'now', ',', 'know', 'that', 'the', 'hypothetical', 'question', 'should', 'start', 'a', 'red', 'light', 'flashing', 'in', 'your', 'mind', '.', 'It', '’', 's', 'your', 'signal', 'that', 'you', 'are', 'about', 'to', 'undergo', 'an', 'increasingly', 'popular', 'type', 'of', 'interview—the', 'case', '(', 'or', 'situational', ')', 'interview', '.', 'If', 'you', 'are', 'seeking', 'a', 'job', 'at', 'a', 'consulting', 'firm', ',', 'law', 'firm', ',', 'or', 'counseling', 'organization', ',', 'you', 'should', 'expect', 'to', 'confront', 'this', 'type', 'of', 'interview', '.', 'The', 'premise', 'is', 'sound', ':', 'Present', 'the', 'candidate', 'with',
# ...

# %% [markdown]
# #SENTENCE SEGMENTATION

# %%
sentences = nltk.sent_tokenize(x.raw())  #whole paragraph break into sentence.
for sentence in sentences:
	print(sentence)
	print()
# Out:
# There’s nothing quite like the terror writes of the hypothetical question.
#
# Especially when it is a written product of the interviewer’s rich imagination.
#
# We’ll talk more about these devils in Chapter 7.
#
# But for now, know that the hypothetical question should start a red light flashing in your mind.
#
# It’s your signal that you are about to undergo an increasingly popular type of interview—the case (or situational) interview.
#
# If you are seeking a job at a consulting firm, law firm, or counseling organization, you should expect to confront this type of interview.
#
# The premise is sound: Present the candidate with situations that might, hypothetically, occur on the job in order to gauge the degree to which he or she demonstrates the traits that will lead to success.
#
# ...

# %% [markdown]
# ## Convert To Lowercase

# %%
text=x.raw()
print(text.lower())
# Out:
# there’s nothing quite like the terror writes of the hypothetical question. especially when it is a written product of the interviewer’s rich imagination. we’ll talk more about these devils in chapter 7. but for now, know that the hypothetical question should start a red light flashing in your mind. it’s your signal that you are about to undergo an increasingly popular type of interview—the case (or situational) interview. if you are seeking a job at a consulting firm, law firm, or counseling organization, you should expect to confront this type of interview. the premise is sound: present the candidate with situations that might, hypothetically, occur on the job in order to gauge the degree to which he or she demonstrates the traits that will lead to success. it’s hard, if not impossible, for you to prepare for these kinds of questions beforehand, which means you’ll have to analyze an unfamiliar problem and develop a strategy to solve it, right then and there. what most interviewers w
# ...

# %% [markdown]
# ## Stop Words Removal

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize



example_sent=x.raw();

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []

for w in word_tokens:
	if w not in stop_words:
		filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)
# Out:
# ['There', '’', 's', 'nothing', 'quite', 'like', 'the', 'terror', 'writes', 'of', 'the', 'hypothetical', 'question', '.', 'Especially', 'when', 'it', 'is', 'a', 'written', 'product', 'of', 'the', 'interviewer', '’', 's', 'rich', 'imagination', '.', 'We', '’', 'll', 'talk', 'more', 'about', 'these', 'devils', 'in', 'Chapter', '7', '.', 'But', 'for', 'now', ',', 'know', 'that', 'the', 'hypothetical', 'question', 'should', 'start', 'a', 'red', 'light', 'flashing', 'in', 'your', 'mind', '.', 'It', '’', 's', 'your', 'signal', 'that', 'you', 'are', 'about', 'to', 'undergo', 'an', 'increasingly', 'popular', 'type', 'of', 'interview—the', 'case', '(', 'or', 'situational', ')', 'interview', '.', 'If', 'you', 'are', 'seeking', 'a', 'job', 'at', 'a', 'consulting', 'firm', ',', 'law', 'firm', ',', 'or', 'counseling', 'organization', ',', 'you', 'should', 'expect', 'to', 'confront', 'this', 'type', 'of', 'interview', '.', 'The', 'premise', 'is', 'sound', ':', 'Present', 'the', 'candidate', 'with',
# ...

# %% [markdown]
# ## Stemming

# %%
# import these modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

# these are the words you can check in the output,the stem of these words is write
#words = ["write", "wrote", "written"]
k=word_tokenize(x.raw())
for w in k:
	print(w, " : ", ps.stem(w))
# Out:
# There  :  there
# ’  :  ’
# s  :  s
# nothing  :  noth
# quite  :  quit
# like  :  like
# the  :  the
# terror  :  terror
# writes  :  write
# of  :  of
# the  :  the
# hypothetical  :  hypothet
# question  :  question
# .  :  .
# Especially  :  especi
# when  :  when
# it  :  it
# is  :  is
# a  :  a
# written  :  written
# product  :  product
# of  :  of
# the  :  the
# interviewer  :  interview
# ’  :  ’
# s  :  s
# rich  :  rich
# imagination  :  imagin
# .  :  .
# We  :  we
# ’  :  ’
# ll  :  ll
# talk  :  talk
# more  :  more
# about  :  about
# these  :  these
# devils  :  devil
# in  :  in
# Chapter  :  chapter
# 7  :  7
# .  :  .
# But  :  but
# for  :  for
# now  :  now
# ,  :  ,
# know  :  know
# that  :  that
# the  :  the
# hypothetical  :  hypothet
# question  :  question
# should  :  should
# start  :  start
# a  :  a
# red  :  red
# light  :  light
# flashing  :  flash
# in  :  in
# your  :  your
# mind  :  mind
# .  :  .
# It  :  it
# ’  :  ’
# s  :  s
# ...

# %% [markdown]
# ## Lemmatization

# %%
#nltk.download('wordnet')
#nltk.download('omw-1.4')
# import these modules
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print("writes :", lemmatizer.lemmatize("writes"))
print("written :", lemmatizer.lemmatize("written"))
# Out:
# writes : writes
# written : written

# %%
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from collections import defaultdict
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

tokens = word_tokenize(x.raw())
lemma_function = WordNetLemmatizer()
for token, tag in pos_tag(tokens):
	 lemma = lemma_function.lemmatize(token, tag_map[tag[0]])
	 print(token, ": ", lemma)
# Out:
# There :  There
# ’ :  ’
# s :  s
# nothing :  nothing
# quite :  quite
# like :  like
# the :  the
# terror :  terror
# writes :  write
# of :  of
# the :  the
# hypothetical :  hypothetical
# question :  question
# . :  .
# Especially :  Especially
# when :  when
# it :  it
# is :  be
# a :  a
# written :  write
# product :  product
# of :  of
# the :  the
# interviewer :  interviewer
# ’ :  ’
# s :  s
# rich :  rich
# imagination :  imagination
# . :  .
# We :  We
# ’ :  ’
# ll :  ll
# talk :  talk
# more :  more
# about :  about
# these :  these
# devils :  devil
# in :  in
# Chapter :  Chapter
# 7 :  7
# . :  .
# But :  But
# for :  for
# now :  now
# , :  ,
# know :  know
# that :  that
# the :  the
# hypothetical :  hypothetical
# question :  question
# should :  should
# start :  start
# a :  a
# red :  red
# light :  light
# flashing :  flash
# in :  in
# your :  your
# mind :  mind
# . :  .
# It :  It
# ’ :  ’
# s :  s
# your :  your
# signal :  signal
# that :  that
# ...

# %% [markdown]
# ## POS Tagging

# %%
import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
stop_words = set(stopwords.words('english'))




tokenized = sent_tokenize(x.raw())
for i in tokenized:
	
	# Word tokenizers is used to find the words
	# and punctuation in a string
	wordsList = nltk.word_tokenize(i)

	# removing stop words from wordList
	wordsList = [w for w in wordsList if not w in stop_words]

	# Using a Tagger. Which is part-of-speech
	# tagger or POS-tagger.
	tagged = nltk.pos_tag(wordsList)

	print(tagged)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [('There', 'EX'), ('’', 'VBZ'), ('nothing', 'NN'), ('quite', 'RB'), ('like', 'IN'), ('terror', 'NN'), ('writes', 'VBZ'), ('hypothetical', 'JJ'), ('question', 'NN'), ('.', '.')]
# [('Especially', 'RB'), ('written', 'VBN'), ('product', 'NN'), ('interviewer', 'NN'), ('’', 'NNP'), ('rich', 'JJ'), ('imagination', 'NN'), ('.', '.')]
# [('We', 'PRP'), ('’', 'VBP'), ('talk', 'VB'), ('devils', 'NNS'), ('Chapter', 'NNP'), ('7', 'CD'), ('.', '.')]
# [('But', 'CC'), (',', ','), ('know', 'VBP'), ('hypothetical', 'JJ'), ('question', 'NN'), ('start', 'NN'), ('red', 'VBD'), ('light', 'JJ'), ('flashing', 'VBG'), ('mind', 'NN'), ('.', '.')]
# ...
